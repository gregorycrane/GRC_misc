# %%
page_breaks = {
    '<p>He begot': '125',
    'In governing his province he': '127',
    'kind of cake.</note></p>': '129',
    'near Thurii that his father': '131',
    'received military prizes at Caesar\'s': '133',
    'the second against Brutus and': '135',
    'with the rank of propraetor, and bidden': '137',
    'To show more plainly that he': '139',
    'could neither satisfy the veterans nor the': '141',
    'pay the rewards promised to his veterans.</p>': '143',
    'Regium by way': '145',
    'Having gone into winter quarters at Samos': '147',
    'as carefully as if they were his own kin.</p>': '149',
    'planned to take his daughter Julia': '151',
    'that were in a state of unrest.</p>': '153',
    'and again after that in Sicily,': '155',
    'when he saw that some tax-': '157',
    'kept them under their original': '159',
    ##
    'demand the office for him in the name of his army; and': '161',
    'who had also been the colleague of his father': '163',
    'dismissed under sentence of': '165',
    'dissatisfaction with the new régime.</p>': '167',
    'He dedicated the': '169',
    'assigned the rest of the high-ways to others who had': '171',
    'solemnly swore that if': '173',
    'seized and kept in confinement': '175',
    'custom of holding court during the': '177',
    'exemption from the obligation to marry after the death of a husband': '179',
    'provided that before taking his seat each member': '181',
    'distribution of grain to the people, as well as the': '183',
    'excused those who were over': '185',
    'distributing to his fellow members of the Fabian': '187',
    'directed the aediles never again to allow': '189',
    'promised, he replied:': '191',
    'not only in the Forum or the amphi': '193',
    'display of the first Parthian hostages that had ever': '195',
    'he decreed that no one': '197',
    'each of the participants according to his deserts.': '199',
    'equal rights and dignity with the city of Rome, by': '201',
    'right of conquest to those from whom he had taken': '203',
    'military treasury, supported by new taxes.</p>': '205',
    "I'll let": '207',
    'and he forbade them to use': '209',
    'At the selection of senators when each member chose': '211',
    'the same laws as the rest and equally liable to': '213',


    ###

    'by fire, the veterans, the guilds, the tribes,': '215',
    'and pay a thank-offering': '217',
    'tie of kinship, he took to': '219',
    'Julia and Agrippina. He married': '221',
    'but he soon disowned': '223',
    'provided by a decree of': '225',
    'although sometimes differences': '227',
    'anything more serious, and': '229',
    'marriage with Livia, with taking the wife': '231',
    'Jupiter himself fled from his golden throne.</l></quote>': '233',
    'He did not in the least': '235',
    'suspicion of any fault. He lived at first': '237',
    'couches and tables still in': '239',
    'and especially story-tellers.<note': '241',
    'either before a dinner party': '243',
    'while he was being': '245',
    'symmetry of his figure, and was': '247',
    'endure either cold or heat.</p>': '249',
    'with little boys, searching': '251',
    'Exhortations to Philosophy</q>': '253',
    'understood. Then': '255',
    'domos</foreign> in the genitive': '257',
    'occasion to use the language,': '259',
    'refuge in an underground': '261',
    'a good omen, betoken': '263',
    'afterwards, from which it was': '265',
    'so that presently she ceased': '267',
    'but after long search he was at': '269',
    'he happened to tell his friends a': '271',
    'unwillingly and hesitatingly, and': '273',
    'equipment of the sacrifice; whereupon the': '275',
    'when he was on the point of sending': '277',
    'belonged to Naples.</note> of whom': '279',
    'which had been established in his honour,': '281',
    'of two Sextuses, Pompeius and': '283',
    'form of the Emperor, after he had been': '285',
    'delay the small amount of': '287'
    
}

page_breaks = {
    'which in the Sabine tongue': '293',
    'her chastity were beyond question;': '295',
    'triumphs, as well as with the': '297',
    '41 B.C.</note> When the': '299',
    'secretly on their way to a ship': '301',
    'different times and in different places, the former in the': '303',
    'He made a plea to the': '305',
    'never before conferred upon anyone.': '307',
    'kissing only a very few when he left.': '309',
    'gradually backed away to his': '311',
    'these, however, were constantly thrust on him, since': '313',
    'which was not agreeable': '315',
    'the day before he was notified that he': '317',
    'the hope of the succession lay in him': '319',
    'crowned with laurel, and mounting a': '321',
    'entered battles with considerably greater confidence': '323',
    'spent an entire day with him in private.': '325',
    'difficulties and such apathy of your army.': '327',
    'written in the name of her': '329',
    'evasive answers and calculating hesitancy keeping': '331',
    '<p>He also feigned': '333',
    'and the placing of the civic': '335',
    "excuse for laying everybody's quarrels before": '337',
    'He forced the commander of a troop of horse, when': '339',
    'bestow everything of the kind. He': '341',
    'acquitted through influence, he would suddenly': '343',
    ##
    'punished according to the decision of a': '345',
    'astrologers as well, but pardoned such': '347',
    'and even this he did only reluctantly and of necessity.': '349',
    'crushed a number of the guests and': '351',
    'and of these I shall give a detailed account from the': '353',
    'vigorously to submit to his lust, he turned her': '357',
    'Hortalus, grandson of Quintus Hortensius the': '359',
    'He did not relieve the provinces either by': '361',
    'he would not allow her even to': '363',
    "of Tiberius' disposition. He in turn was so put out": '365',
    'that he made light of his illustrious deeds as un-': '367',
    'he had her beaten by a centurion until one of her eyes': '369',
    'It is thought that Nero was forced to take his own life, since an executioner,': '371',
    'His teacher of rhetoric, Theodorus of Gadara, seems first': '373',
    'to carry a ring or coin stamped with his image into a privy or a brothel, or to criticize any': '375',
    'Hands stained with blood not once, dripping again and again;': '377',
    'After the death of Sejanus he was more cruel than ever, which showed': '379',
    'feeling sure of being condemned and wishing to avoid': '381',
    'there was no one whom Tiberius spared from torment and death. Indeed, he gave himself up so utterly for': '383',
    'how hated and execrable he was all this time, but also that he lived a life of extreme fear and was even exposed': '385',
    'he accused him when he least expected it in a shameful and pitiable speech, begging the senators among other things': '387',
    'counselling him to gratify the intense and just hatred of the citizens as soon as possible by a voluntary death.': '389',
    'He was large and strong of frame, and of a stature above the average; broad of shoulders': '391',
    'firmly convinced that everything was in the hands of fate, he was nevertheless immoderately afraid of thunder. Whenever the sky was lowering,': '393',
    'he would not use it on all occasions, and especially eschewed it in the senate; so much': '395',
    'all that, he kept up for some time, although he': '397',
    'Some say that a pillow was thrown upon his face, when he came to and asked for a ring which had been taken from him during a fainting': '399',
    'punishment of some fell due on the day when the news came about Tiberius. The poor wretches': '401'
}


page_breaks = {
    'steeped in poison it cannot be destroyed by fire.': '407',
    'whosoever they were and whatever their motives, he was so': '409',
    "put off their beards and had their wives' heads shaved, as": '411',
    'in the guise of Cupid, Livia dedicated in the temple': '413',
    'Pliny has': '415',
    'derived from a joke of the troops, because he was brought up in their': '417',
    'even at that time he could not control': '419',
    'suspecting that he was trying to hold fast to it, that a pillow be put over his face;': '421',
    'and no attention was paid to the wish of Tiberius, who in his will had': '423',
    'with a banner set in the stern, and from there up the Tiber': '425',
    'He refused a note which was offered him regarding his own safety, maintaining that': '427',
    'To make it known that he encouraged every kind of': '429',
    'pairs of African and': '431',
    'Over this bridge he rode back and forth for two successive days, the first day on a': '433',
    'completed the public works which had been half finished under Tiberius, namely the temple': '435',
    'should be brought from': '437',
    'included Agrippa among the ancestors of the Caesars. He even boasted that': '439',
    'medicine for a chronic cough, which was growing worse. As for his uncle': '441',
    'often prostituted them to his favourites; so that he': '443',
    'he carried to the temples of all the goddesses, finally placing': '445',
    'secure the free seats in the Circus, he drove them all out': '447',
    'offered his life for the same reason, but delayed to kill himself, he turned': '449',
    'thinking that his exiles were likewise praying for his death,': '451',
    'put to death except by numerous slight wounds, his constant order, which': '453',
    'the collapse of the amphitheatre at Fidenae, while his own was threatened with': '455',
    'What do you suppose,': '457',
    'intending to do away with any practice of their profession,': '459',
    'for setting his slave free after a victory, Caligula': '461',
    'inventing a new sort of baths and unnatural varieties of food': '463',
    'since <q rend="double">descendants</q>': '465',

    ##
    'possessions, opened their veins. A well-known': '467',
    'He levied new and unheard of taxes, at': '469',
    'even disdain to make money from play, and to': '471',
    'were forced, contrary to all precedent, to lay their': '473',
    'confusion that the enemy were close at hand. Upon': '475',
    'As a monument': '477',
    'legionaries, suspecting his purpose, were stealing off': '479',
    'poisons, which they say were later thrown into the sea': '481',
    'and now wander through the long colonnades, crying': '483',
    'terror at the report of a defeat.': '485',
    'accusations and defences of important personages': '487',
    'if anyone made even the slightest sound while his': '489',
    'waiting for a favourable opportunity, two men made': '491',
    'danger was threatened to the owner at the hands of': '493',
    'persuasion of his friends. In the covered passage': '495',
    'exile dug it up, cremated it, and consigned it to': '497'
    
}

## volume 2 -- life of Claudius

page_breaks = {
    'apparition of a barbarian woman of greater than': '5',
    'did not obey at once, took him off by poison. This': '7',
    'muleteers, put in charge of him for the express': '9',
    'decide once for all what plan we are to adopt in his case. For if': '11',
    'invite the young Tiberius to dinner every day during your absence, to keep him': '13',
    'incurred the reproach of drunkenness and gambling, in addition to his former reputation for dulness.': '15',
    'an eagle that was flying by lit upon his shoulder. He was': '17',
    'Moreover, from that time on he always gave': '19',
    'Then he took him to the rest of': '21',
    'both to make an example of them and because he knew': '23',
    'He obtained from the': '25',
    'Asinius Gallus and Statilius Corvinus, grandsons': '27',
    'sometimes hasty and inconsiderate, occasionally silly and like a crazy man. In revising': '29',
    'By such acts as these he so discredited himself that he was held in general and open contempt. One man': '31',
    'Another who was notorious for corruption and adultery he merely admonished to be more': '33',
    'bountiful, the wine jars': '35',
    'He always gave scrupulous attention to': '37',
    'although in the case of the last two he': '39',
    'in places where no one had ever given': '41',
    'wild bulls all over the arena, leaping upon them': '43',
    'the surrender of the kings of the Britons, and': '45',
    ' a summer term, he made': '47',
    'Even then, fearful of criticism, he declared that the censor Appius Caecus, the ancient founder of his': '49',
    'to pay their respects. He': '51',
    'reading an ancient letter of the senate and people of': '53',
    'to Aemilia Lepida, great-granddaughter of Augustus,': '55',
    'Pompeius and Silanus he not only declined to adopt, but even put to death.': '59',
    ' Appius Silanus and the two Julias, daughters of': '61',
    'his anger still more': '63',
    'then he went to sleep at once, lying on his back with his mouth open,': '65',
    'that he would go down to the arena at daybreak and after dismissing the people': '67',
    'a man with a dagger was caught near him as he was sacrificing, he': '69',
    'was reported to be forcing his way in, and as if this were proof positive': '71',
    'otherwise he could not have escaped alive and attained his present station. But he convinced no one, and': '73',
    'before the senate, he said: <q rend="double">This': '75',
    'both by his mother and his': '77',
    'twenty books of Etruscan History and eight of Carthaginian. Because of these works there was': '79',
    'with the priests;': '81',
    ', and that he made no secret': '83'
}

## Life of Nero

page_breaks = {
    'It seems to me worth': '89',
    'kill himself in a fit of despair and terror, he so': '91',
    'father of the Domitius who was': '93',
    'he was held up to scorn by the jests of his own sister, and': '95',
    'aunt Lepida almost in actual want, under two tutors,': '97',
    'that Britannicus was a changeling. Also': '99',
    'gave Claudius a magnificent funeral, spoke his': '101',
    'exercises in the Campus, and often declaimed in public.': '103',
    'amphitheatre, erected in the district of': '105',
    'Then he went down into the orchestra among the senators': '107',
    ' again done obeisance,<note resp="editor">Cf. Aug. xliv. 3.</note> ': '109',
    'even on men of the': '111',

    'praetorians and urged them to begin the work; then': '115',
    'In the same city he sang frequently': '117',
    'prefects of the Guard': '119',
    'he told a lie and pretended that he was': '121',
    'appearance as a singer at the altar of': '123',
    'done all that could be done, but the issue was in the': '125',
    'at the same time gave the judges Roman citizenship': '127',
    'except by letter or in a speech delivered by another, to save': '129',
    'they came to blows and fought with stones and broken benches, he': '131',
    'And the witty jest that someone made is still': '133',
    'He thought that there was no other way of': '135',
    'Its size and splendour will be sufficiently indicated by the': '137'
}


fname = 'save/suetonius.nero.loeb_eng1.xml'
f = open(fname)
import re
text = f.read()

for pat in page_breaks:
    curtag = ' <pb n="' + page_breaks[pat] + '"/> '
    text,n = re.subn(pat,pat+curtag,text)
    if(not n == 1):
        print(n,pat,curtag)

f.close()

outfname = re.sub('save/','',fname)
print(fname,outfname)

outf = open(outfname,'w')
outf.write(text)
outf.close()
# Out:
# save/suetonius.nero.loeb_eng1.xml suetonius.nero.loeb_eng1.xml
