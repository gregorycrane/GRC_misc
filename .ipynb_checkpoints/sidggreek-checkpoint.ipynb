# %%
import re

def dogrc(fname):
    innotes = 0
    outfname = re.sub('1\.xml','2.xml',fname)
    f = open(fname)
    curlnum = 0
    outf = open(outfname,'w')
    for l in f:
        l = re.sub('\s+$','',l)
        l = re.sub('^[0-9]+$','',l)
        if(not l):
            continue


        
        if(re.search('<pb',l)):
            if(innotes):
                print('</note>',file=outf)
                
            innotes = 0
            print(l,file=outf)
            continue
        if(re.search('<note/>',l)):
            innotes = 1
            print('<note>',file=outf)
            continue

        if(innotes):
            l = re.sub('^([0-9]+)\.\s+(.+)','<ref target="\g<1>">\g<2></ref>',l)
            print(l,file=outf)
            continue
        l = re.sub('(.+)\s+([0-9]+)$','<l n="\g<2>">\g<1></l>',l)
        l = re.sub('(ἀντ\.|στρ\.)([^<]+)','<milestone unit="strophe" n="\g<1>\g<2>"/>',l)
        l = re.sub('\*\s*([^,\.\s;]+)','<lem>\g<1></lem>',l)
        m = re.search('<l n="([0-9]+)',l)
        if(m):
            tmplnum = int(m[1])
            if(not tmplnum == curlnum + 1):
                print('jump',curlnum,tmplnum,l)
            curlnum = tmplnum
            print(l,file=outf)
            continue
        if(re.search('<',l)):
            print(l,file=outf)
            continue
        curlnum = curlnum + 1
        print('<l n="'+str(curlnum)+'">'+l+'</l>',file=outf)
    print(fname,outfname)
    

dogrc('aesch.eum.sidgwick-grc1.xml')
# Out:
# jump 173 180 <l n="180">χωρεῖτ᾽, ἀπαλλάσσεσθε μαντικῶν μυχῶν·</l>
# jump 253 255 <l n="255">ὅρα, ὅρα μάλ᾽ αὖ, λεῦσσέ * τε πάντα μὴ</l>
# jump 258 260 <l n="260">ὑπόδικος θέλει γενέσθαι χερῶν.</l>
# jump 332 335 <l n="335">μοῖρ᾽ ἐπέκλωσεν ἐμπέδως ἔχειν,</l>
# jump 346 350 <l n="350">ἀθανάτων δ᾽ ἀπέχειν χέρας, οὐδέ τις ἐστὶ</l>
# jump 353 355 <l n="355">ἀνατροπάς, ὅταν Ἄης</l>
# jump 363 366 <l n="366">ὡς ἀπηξιώσατο, -</l>
# jump 373 375 <l n="375">ἁμετέραις ἐφόδοις μελανείμοσιν, ὀρχησ-</l>
# jump 378 380 <l n="380">ται πολύστονος φάτις.</l>
# jump 383 385 <l n="385">ἄτιμ᾿ ἀτιετα διόμεναι</l>
# jump 388 390 <l n="390">τε καὶ δέδοικεν βροτῶν,</l>
# jump 493 495 <l n="495">α ξυναρμόσει βροτούς.</l>
# jump 498 500 <l n="500">μαινάδων τῶνδ᾽ ἐφέρ-</l>
# jump 517 520 <l n="520">ξυμφέρει</l>
# jump 527 530 <l n="530">παντὶ μέσῳ τὸ κράτος θεὸς ὤπασεν·</l>
# jump 538 540 <l n="540">μηδέ νιν</l>
# jump 548 550 <l n="550">οὐκ ἄνολβος ἔσται·</l>
# jump 553 555 <l n="555">βιαίως ξὺν χρόνῳ καθήσειν,</l>
# jump 558 560 <l n="560">γελᾷ δὲ δαίμων ἐπ᾽ ἀνδρὶ θερμῷ,</l>
# jump 791 794 <l n="794">ἐμοὶ πίθεσθε μὴ βαρυστόνως φέρειν</l>
# jump 828 830 <l n="830">γλώσσης ματαίας μὴ ἐκβάλῃς * ἔπη χθονὶ</l>
# jump 848 850 <l n="850">φρονεῖν δὲ κἀμοὶ Ζεὺς ἔδωκεν οὐ κακῶς.</l>
# jump 931 935 <l n="935">πρὸς τάσδ᾽ ἀπάγει, σιγῶν * δ᾽ ὄλεθρος</l>
# jump 938 940 <l n="940">† φλογμός τ' ὀμματοστερὴς</l>
# jump 943 945 <l n="945">ξὺν διπλοῖσιν ἐμβρύοις</l>
# jump 958 960 <l n="960">δότε, κύρι᾽ ἔχοντες,</l>
# jump 963 965 <l n="965">παντὶ χρόνῳ δ᾽ ἐπιβριθεῖς</l>
# jump 978 980 <l n="980">μέλαν αἷμα πολιτᾶν</l>
# jump 998 1000 <l n="1000">σωφρονοῦντες ἐν χρόνῳ.</l>
# jump 1034 1040 <l n="1040">ἵλαοι δὲ καὶ εὐθύφρονες γᾷ <milestone unit="strophe" n="στρ. β'."/></l>
# jump 1043 1045 <l n="1045">Παλλάδος ἀστοῖς Ζεὺς * ὁ πανόπτας</l>
# aesch.eum.sidgwick-grc1.xml aesch.eum.sidgwick-grc2.xml
